# %% [markdown]
# ## Feature Engineering and Model Training Pipeline for Combined Datasets

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/interim/student-full-encoded.csv")
df.head()
# Out:
#    absences  studytime  freetime  health  goout  Dalc  Walc  higher_yes  \
# 0         6          2         3       3      4     1     1        True
# 1         4          2         3       3      3     1     1        True
# 2        10          2         3       3      2     2     3        True
# 3         2          3         2       5      2     1     1        True
# 4         4          2         3       5      2     1     2        True
#
#    schoolsup_yes  romantic_yes  ...  Mjob_other  Mjob_services  Mjob_teacher  \
# 0           True         False  ...       False          False         False
# 1          False         False  ...       False          False         False
# 2           True         False  ...       False          False         False
# 3          False          True  ...       False          False         False
# 4          False         False  ...        True          False         False
#
#    reason_home  reason_other  reason_reputation  internet_yes  sex_M  \
# 0        False         False              False         False  False
# 1        False         False              False          True  False
# 2        False          True              False          True  False
# 3         True         False              False          True  False
# 4         True         False              False         False  False
#
#    subject_por  at_risk
# 0        False      1.0
# 1        False      1.0
# 2        False      0.0
# 3        False      0.0
# 4        False      0.0
#
# [5 rows x 24 columns]

# %%
df.info()
df["at_risk"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   absences           662 non-null    int64
#  1   studytime          662 non-null    int64
#  2   freetime           662 non-null    int64
#  3   health             662 non-null    int64
#  4   goout              662 non-null    int64
#  5   Dalc               662 non-null    int64
#  6   Walc               662 non-null    int64
#  7   higher_yes         662 non-null    bool
#  8   schoolsup_yes      662 non-null    bool
#  9   romantic_yes       662 non-null    bool
#  10  paid_yes           662 non-null    bool
#  11  guardian_mother    662 non-null    bool
#  12  guardian_other     662 non-null    bool
#  13  Mjob_health        662 non-null    bool
#  14  Mjob_other         662 non-null    bool
#  15  Mjob_services      662 non-null    bool
#  16  Mjob_teacher       662 non-null    bool
#  17  reason_home        662 non-null    bool
#  18  reason_other       662 non-null    bool
#  19  reason_reputation  662 non-null    bool
#  20  internet_yes       662 non-null    bool
#  21  sex_M              662 non-null    bool
#  22  subject_por        662 non-null    bool
#  23  at_risk            422 non-null    float64
# dtypes: bool(16), float64(1), int64(7)
# memory usage: 51.8 KB
# at_risk
# 0.0    285
# 1.0    137
# Name: count, dtype: int64

# %% [markdown]
# ### Binning Numeric Values

# %%
df["absences_bin"] = pd.cut(df["absences"], bins=[-1, 0, 3, 10, 50], labels=["none", "low", "medium", "high"])
df["goout_binned"] = pd.cut(df["goout"], bins=[-1, 2, 4, 5], labels=["low", "medium", "high"])

# %% [markdown]
# Alcohol Score

# %%
df["alc_total"] = df["Dalc"] + df["Walc"]

# %%
df["alc_level"] = pd.cut(df["alc_total"], bins=[0, 3, 5, 10], labels=["low", "moderate", "high"])

# %% [markdown]
# Interaction features

# %%
df["study_absence_ratio"] = df["studytime"] / (df["absences"] + 1)
df["alc_goout"] = df["alc_total"] * df["goout"]

# %% [markdown]
# ### One hot Encoding Categorical Variables

# %%
df = pd.get_dummies(df, columns=["absences_bin", "goout_binned", "alc_level"], drop_first=True)

# %%
df.head()
# Out:
#    absences  studytime  freetime  health  goout  Dalc  Walc  higher_yes  \
# 0         6          2         3       3      4     1     1        True
# 1         4          2         3       3      3     1     1        True
# 2        10          2         3       3      2     2     3        True
# 3         2          3         2       5      2     1     1        True
# 4         4          2         3       5      2     1     2        True
#
#    schoolsup_yes  romantic_yes  ...  alc_total  study_absence_ratio  \
# 0           True         False  ...          2             0.285714
# 1          False         False  ...          2             0.400000
# 2           True         False  ...          5             0.181818
# 3          False          True  ...          2             1.000000
# 4          False         False  ...          3             0.400000
#
#    alc_goout  absences_bin_low  absences_bin_medium  absences_bin_high  \
# 0          8             False                 True              False
# 1          6             False                 True              False
# 2         10             False                 True              False
# 3          4              True                False              False
# 4          6             False                 True              False
#
#    goout_binned_medium  goout_binned_high  alc_level_moderate  alc_level_high
# 0                 True              False               False           False
# 1                 True              False               False           False
# 2                False              False                True           False
# 3                False              False               False           False
# 4                False              False               False           False
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Save the engineered dataset

# %%
df.to_csv("../../data/interim/student-final-engineered.csv", index=False)
